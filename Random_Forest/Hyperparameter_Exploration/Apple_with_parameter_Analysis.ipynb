# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshit-Chouksey/CMPE257_Project_Market_Trends/blob/main/Random_Forest/Hyperparameter_Exploration/Apple_with_parameter_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Function to get historical stock data using Yahoo Finance API
def get_stock_data(ticker, start_date, end_date):
    stock_data = yf.download(ticker, start=start_date, end=end_date)
    return stock_data

# Function to create features for prediction
def create_features(data):
    data['Date'] = data.index
    data['Year'] = data['Date'].dt.year
    data['Month'] = data['Date'].dt.month
    data['Day'] = data['Date'].dt.day
    data = data.drop(['Date'], axis=1)
    return data

# Function to train and evaluate the Random Forest model
def train_random_forest(data, n_estimators, max_depth, min_samples_split, min_samples_leaf, max_features):
    X = data.drop(['Close'], axis=1)
    y = data['Close']

    # Split the data into training and testing sets (70% train, 30% test)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    # Initialize the Random Forest model
    model = RandomForestRegressor(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        random_state=42
    )

    # Train the model
    model.fit(X_train, y_train)

    # Make predictions on the test set
    predictions = model.predict(X_test)

    # Evaluate the model
    mse = mean_squared_error(y_test, predictions)
    print(f'Mean Squared Error (n_estimators={n_estimators}, max_depth={max_depth}, min_samples_split={min_samples_split}, min_samples_leaf={min_samples_leaf}, max_features={max_features}): {mse}')

if __name__ == "__main__":
    # Set the stock symbol, start date, and end date (last 5 years)
    stock_symbol = 'AAPL'
    end_date = pd.to_datetime('today')
    start_date = end_date - pd.DateOffset(years=5)

    # Get historical stock data
    stock_data = get_stock_data(stock_symbol, start_date, end_date)

    # Create features for prediction
    stock_data_features = create_features(stock_data)

    # Define variations of hyperparameters to test
    n_estimators_values = [100, 200]
    max_depth_values = [None, 10, 20]
    min_samples_split_values = [2, 5]
    min_samples_leaf_values = [1, 2]
    max_features_values = [1.0, 'sqrt', 0.5]

    # Iterate over variations and train/evaluate the model
    for n_estimators in n_estimators_values:
        for max_depth in max_depth_values:
            for min_samples_split in min_samples_split_values:
                for min_samples_leaf in min_samples_leaf_values:
                    for max_features in max_features_values:
                        train_random_forest(
                            stock_data_features,
                            n_estimators=n_estimators,
                            max_depth=max_depth,
                            min_samples_split=min_samples_split,
                            min_samples_leaf=min_samples_leaf,
                            max_features=max_features
                        )
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Mean Squared Error (n_estimators=100, max_depth=None, min_samples_split=2, min_samples_leaf=1, max_features=1.0): 0.22410452723654659
# Mean Squared Error (n_estimators=100, max_depth=None, min_samples_split=2, min_samples_leaf=1, max_features=sqrt): 0.7687341570944005
# Mean Squared Error (n_estimators=100, max_depth=None, min_samples_split=2, min_samples_leaf=1, max_features=0.5): 0.3441566350766373
# Mean Squared Error (n_estimators=100, max_depth=None, min_samples_split=2, min_samples_leaf=2, max_features=1.0): 0.22500720232339919
# Mean Squared Error (n_estimators=100, max_depth=None, min_samples_split=2, min_samples_leaf=2, max_features=sqrt): 0.9335716055552138
# Mean Squared Error (n_estimators=100, max_depth=None, min_samples_split=2, min_samples_leaf=2, max_features=0.5): 0.3536619701442245
# Mean Squared Error (n_estimators=100, max_depth=None, min_samples_split=5, min_samples_leaf=1, max_features=1.0): 0.22968250993096995
# Mean Squared Error (n_estimators=100, max_depth=None, min_samples_split=5, min_samples_leaf=1, max_features=sqrt): 0.8704434056569978
# Mean Squared Error (n_estimators=100, max_depth=None, min_samples_split=5, min_samples_leaf=1, max_features=0.5): 0.3640987037803785
# Mean Squared Error (n_estimators=100, max_depth=None, min_samples_split=5, min_samples_leaf=2, max_features=1.0): 0.23110017137473757
# Mean Squared Error (n_estimators=100, max_depth=None, min_samples_split=5, min_samples_leaf=2, max_features=sqrt): 0.9052535905424088
# Mean Squared Error (n_estimators=100, max_depth=None, min_samples_split=5, min_samples_leaf=2, max_features=0.5): 0.3617804550193603
# Mean Squared Error (n_estimators=100, max_depth=10, min_samples_split=2, min_samples_leaf=1, max_features=1.0): 0.22014331309582785
# Mean Squared Error (n_estimators=100, max_depth=10, min_samples_split=2, min_samples_leaf=1, max_features=sqrt): 0.8340617137362534
# Mean Squared Error (n_estimators=100, max_depth=10, min_samples_split=2, min_samples_leaf=1, max_features=0.5): 0.33289631730864533
# Mean Squared Error (n_estimators=100, max_depth=10, min_samples_split=2, min_samples_leaf=2, max_features=1.0): 0.22107348398643878
# Mean Squared Error (n_estimators=100, max_depth=10, min_samples_split=2, min_samples_leaf=2, max_features=sqrt): 0.8947515111360298
# Mean Squared Error (n_estimators=100, max_depth=10, min_samples_split=2, min_samples_leaf=2, max_features=0.5): 0.348951126071243
# Mean Squared Error (n_estimators=100, max_depth=10, min_samples_split=5, min_samples_leaf=1, max_features=1.0): 0.22913116909699666
# Mean Squared Error (n_estimators=100, max_depth=10, min_samples_split=5, min_samples_leaf=1, max_features=sqrt): 0.9522453556491398
# Mean Squared Error (n_estimators=100, max_depth=10, min_samples_split=5, min_samples_leaf=1, max_features=0.5): 0.378770157894077
# Mean Squared Error (n_estimators=100, max_depth=10, min_samples_split=5, min_samples_leaf=2, max_features=1.0): 0.23250945414509558
# Mean Squared Error (n_estimators=100, max_depth=10, min_samples_split=5, min_samples_leaf=2, max_features=sqrt): 0.9153261750061249
# Mean Squared Error (n_estimators=100, max_depth=10, min_samples_split=5, min_samples_leaf=2, max_features=0.5): 0.3630841452867325
# Mean Squared Error (n_estimators=100, max_depth=20, min_samples_split=2, min_samples_leaf=1, max_features=1.0): 0.22410452723654659
# Mean Squared Error (n_estimators=100, max_depth=20, min_samples_split=2, min_samples_leaf=1, max_features=sqrt): 0.7687341570944005
# Mean Squared Error (n_estimators=100, max_depth=20, min_samples_split=2, min_samples_leaf=1, max_features=0.5): 0.3441566350766373
# Mean Squared Error (n_estimators=100, max_depth=20, min_samples_split=2, min_samples_leaf=2, max_features=1.0): 0.22500720232339919
# Mean Squared Error (n_estimators=100, max_depth=20, min_samples_split=2, min_samples_leaf=2, max_features=sqrt): 0.9335716055552138
# Mean Squared Error (n_estimators=100, max_depth=20, min_samples_split=2, min_samples_leaf=2, max_features=0.5): 0.3536619701442245
# Mean Squared Error (n_estimators=100, max_depth=20, min_samples_split=5, min_samples_leaf=1, max_features=1.0): 0.22968250993096995
# Mean Squared Error (n_estimators=100, max_depth=20, min_samples_split=5, min_samples_leaf=1, max_features=sqrt): 0.8704434056569978
# Mean Squared Error (n_estimators=100, max_depth=20, min_samples_split=5, min_samples_leaf=1, max_features=0.5): 0.3640987037803785
# Mean Squared Error (n_estimators=100, max_depth=20, min_samples_split=5, min_samples_leaf=2, max_features=1.0): 0.23110017137473757
# Mean Squared Error (n_estimators=100, max_depth=20, min_samples_split=5, min_samples_leaf=2, max_features=sqrt): 0.9052535905424088
# Mean Squared Error (n_estimators=100, max_depth=20, min_samples_split=5, min_samples_leaf=2, max_features=0.5): 0.3617804550193603
# Mean Squared Error (n_estimators=200, max_depth=None, min_samples_split=2, min_samples_leaf=1, max_features=1.0): 0.22287433624242173
# Mean Squared Error (n_estimators=200, max_depth=None, min_samples_split=2, min_samples_leaf=1, max_features=sqrt): 0.7512292504951592
# Mean Squared Error (n_estimators=200, max_depth=None, min_samples_split=2, min_samples_leaf=1, max_features=0.5): 0.3354993436503309
# Mean Squared Error (n_estimators=200, max_depth=None, min_samples_split=2, min_samples_leaf=2, max_features=1.0): 0.22493475216761885
# Mean Squared Error (n_estimators=200, max_depth=None, min_samples_split=2, min_samples_leaf=2, max_features=sqrt): 0.8983398527537012
# Mean Squared Error (n_estimators=200, max_depth=None, min_samples_split=2, min_samples_leaf=2, max_features=0.5): 0.3513670795327959
# Mean Squared Error (n_estimators=200, max_depth=None, min_samples_split=5, min_samples_leaf=1, max_features=1.0): 0.22761462953750958
# Mean Squared Error (n_estimators=200, max_depth=None, min_samples_split=5, min_samples_leaf=1, max_features=sqrt): 0.8663668302234174
# Mean Squared Error (n_estimators=200, max_depth=None, min_samples_split=5, min_samples_leaf=1, max_features=0.5): 0.35367042073236044
# Mean Squared Error (n_estimators=200, max_depth=None, min_samples_split=5, min_samples_leaf=2, max_features=1.0): 0.22662155390275376
# Mean Squared Error (n_estimators=200, max_depth=None, min_samples_split=5, min_samples_leaf=2, max_features=sqrt): 0.8796840839882584
# Mean Squared Error (n_estimators=200, max_depth=None, min_samples_split=5, min_samples_leaf=2, max_features=0.5): 0.35803102267661713
# Mean Squared Error (n_estimators=200, max_depth=10, min_samples_split=2, min_samples_leaf=1, max_features=1.0): 0.21939757883809757
# Mean Squared Error (n_estimators=200, max_depth=10, min_samples_split=2, min_samples_leaf=1, max_features=sqrt): 0.7902277192121886
# Mean Squared Error (n_estimators=200, max_depth=10, min_samples_split=2, min_samples_leaf=1, max_features=0.5): 0.3327575353213748
# Mean Squared Error (n_estimators=200, max_depth=10, min_samples_split=2, min_samples_leaf=2, max_features=1.0): 0.22283523907003716
# Mean Squared Error (n_estimators=200, max_depth=10, min_samples_split=2, min_samples_leaf=2, max_features=sqrt): 0.8630587758013077
# Mean Squared Error (n_estimators=200, max_depth=10, min_samples_split=2, min_samples_leaf=2, max_features=0.5): 0.347667887131915
# Mean Squared Error (n_estimators=200, max_depth=10, min_samples_split=5, min_samples_leaf=1, max_features=1.0): 0.22807488881253674
# Mean Squared Error (n_estimators=200, max_depth=10, min_samples_split=5, min_samples_leaf=1, max_features=sqrt): 0.8956234450105188
# Mean Squared Error (n_estimators=200, max_depth=10, min_samples_split=5, min_samples_leaf=1, max_features=0.5): 0.36929185594160285
# Mean Squared Error (n_estimators=200, max_depth=10, min_samples_split=5, min_samples_leaf=2, max_features=1.0): 0.22738747362289807
# Mean Squared Error (n_estimators=200, max_depth=10, min_samples_split=5, min_samples_leaf=2, max_features=sqrt): 0.8635980249548304
# Mean Squared Error (n_estimators=200, max_depth=10, min_samples_split=5, min_samples_leaf=2, max_features=0.5): 0.362342971448497
# Mean Squared Error (n_estimators=200, max_depth=20, min_samples_split=2, min_samples_leaf=1, max_features=1.0): 0.22287433624242173
# Mean Squared Error (n_estimators=200, max_depth=20, min_samples_split=2, min_samples_leaf=1, max_features=sqrt): 0.7512292504951592
# Mean Squared Error (n_estimators=200, max_depth=20, min_samples_split=2, min_samples_leaf=1, max_features=0.5): 0.3354993436503309
# Mean Squared Error (n_estimators=200, max_depth=20, min_samples_split=2, min_samples_leaf=2, max_features=1.0): 0.22493475216761885
# Mean Squared Error (n_estimators=200, max_depth=20, min_samples_split=2, min_samples_leaf=2, max_features=sqrt): 0.8983398527537012
# Mean Squared Error (n_estimators=200, max_depth=20, min_samples_split=2, min_samples_leaf=2, max_features=0.5): 0.3513670795327959
# Mean Squared Error (n_estimators=200, max_depth=20, min_samples_split=5, min_samples_leaf=1, max_features=1.0): 0.22761462953750958
# Mean Squared Error (n_estimators=200, max_depth=20, min_samples_split=5, min_samples_leaf=1, max_features=sqrt): 0.8663668302234174
# Mean Squared Error (n_estimators=200, max_depth=20, min_samples_split=5, min_samples_leaf=1, max_features=0.5): 0.35367042073236044
# Mean Squared Error (n_estimators=200, max_depth=20, min_samples_split=5, min_samples_leaf=2, max_features=1.0): 0.22662155390275376
# Mean Squared Error (n_estimators=200, max_depth=20, min_samples_split=5, min_samples_leaf=2, max_features=sqrt): 0.8796840839882584
# Mean Squared Error (n_estimators=200, max_depth=20, min_samples_split=5, min_samples_leaf=2, max_features=0.5): 0.35803102267661713
