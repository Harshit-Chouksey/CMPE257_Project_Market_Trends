# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshit-Chouksey/CMPE257_Project_Market_Trends/blob/main/Random_Forest/Hyperparameter_Exploration/Tesla_with_parameter_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Function to get historical stock data using Yahoo Finance API
def get_stock_data(ticker, start_date, end_date):
    stock_data = yf.download(ticker, start=start_date, end=end_date)
    return stock_data

# Function to create features for prediction
def create_features(data):
    data['Date'] = data.index
    data['Year'] = data['Date'].dt.year
    data['Month'] = data['Date'].dt.month
    data['Day'] = data['Date'].dt.day
    data = data.drop(['Date'], axis=1)
    return data

# Function to train and evaluate the Random Forest model
def train_random_forest(data, n_estimators, max_depth, min_samples_split, min_samples_leaf, max_features):
    X = data.drop(['Close'], axis=1)
    y = data['Close']

    # Split the data into training and testing sets (70% train, 30% test)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    # Initialize the Random Forest model
    model = RandomForestRegressor(
        n_estimators=n_estimators,
        max_depth=max_depth,
        min_samples_split=min_samples_split,
        min_samples_leaf=min_samples_leaf,
        max_features=max_features,
        random_state=42
    )

    # Train the model
    model.fit(X_train, y_train)

    # Make predictions on the test set
    predictions = model.predict(X_test)

    # Evaluate the model
    mse = mean_squared_error(y_test, predictions)
    print(f'Mean Squared Error (n_estimators={n_estimators}, max_depth={max_depth}, min_samples_split={min_samples_split}, min_samples_leaf={min_samples_leaf}, max_features={max_features}): {mse}')

if __name__ == "__main__":
    # Set the stock symbol, start date, and end date (last 5 years)
    stock_symbol = 'TSLA'
    end_date = pd.to_datetime('today')
    start_date = end_date - pd.DateOffset(years=5)

    # Get historical stock data
    stock_data = get_stock_data(stock_symbol, start_date, end_date)

    # Create features for prediction
    stock_data_features = create_features(stock_data)

    # Define variations of hyperparameters to test
    n_estimators_values = [100, 200]
    max_depth_values = [None, 10, 20]
    min_samples_split_values = [2, 5]
    min_samples_leaf_values = [1, 2]
    max_features_values = [1.0, 'sqrt', 0.5]

    # Iterate over variations and train/evaluate the model
    for n_estimators in n_estimators_values:
        for max_depth in max_depth_values:
            for min_samples_split in min_samples_split_values:
                for min_samples_leaf in min_samples_leaf_values:
                    for max_features in max_features_values:
                        train_random_forest(
                            stock_data_features,
                            n_estimators=n_estimators,
                            max_depth=max_depth,
                            min_samples_split=min_samples_split,
                            min_samples_leaf=min_samples_leaf,
                            max_features=max_features
                        )
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Mean Squared Error (n_estimators=100, max_depth=None, min_samples_split=2, min_samples_leaf=1, max_features=1.0): 0.8006238359940882
# Mean Squared Error (n_estimators=100, max_depth=None, min_samples_split=2, min_samples_leaf=1, max_features=sqrt): 7.510508757491216
# Mean Squared Error (n_estimators=100, max_depth=None, min_samples_split=2, min_samples_leaf=1, max_features=0.5): 2.449629064419471
# Mean Squared Error (n_estimators=100, max_depth=None, min_samples_split=2, min_samples_leaf=2, max_features=1.0): 0.7373177183942361
# Mean Squared Error (n_estimators=100, max_depth=None, min_samples_split=2, min_samples_leaf=2, max_features=sqrt): 7.655069115443085
# Mean Squared Error (n_estimators=100, max_depth=None, min_samples_split=2, min_samples_leaf=2, max_features=0.5): 2.3983456093697204
# Mean Squared Error (n_estimators=100, max_depth=None, min_samples_split=5, min_samples_leaf=1, max_features=1.0): 0.9535904732430501
# Mean Squared Error (n_estimators=100, max_depth=None, min_samples_split=5, min_samples_leaf=1, max_features=sqrt): 7.889183544686425
# Mean Squared Error (n_estimators=100, max_depth=None, min_samples_split=5, min_samples_leaf=1, max_features=0.5): 2.4797693890943493
# Mean Squared Error (n_estimators=100, max_depth=None, min_samples_split=5, min_samples_leaf=2, max_features=1.0): 0.7306269910810763
# Mean Squared Error (n_estimators=100, max_depth=None, min_samples_split=5, min_samples_leaf=2, max_features=sqrt): 8.345346418556733
# Mean Squared Error (n_estimators=100, max_depth=None, min_samples_split=5, min_samples_leaf=2, max_features=0.5): 2.4957066743981247
# Mean Squared Error (n_estimators=100, max_depth=10, min_samples_split=2, min_samples_leaf=1, max_features=1.0): 0.8420741780436513
# Mean Squared Error (n_estimators=100, max_depth=10, min_samples_split=2, min_samples_leaf=1, max_features=sqrt): 7.584274983976525
# Mean Squared Error (n_estimators=100, max_depth=10, min_samples_split=2, min_samples_leaf=1, max_features=0.5): 2.675438405472697
# Mean Squared Error (n_estimators=100, max_depth=10, min_samples_split=2, min_samples_leaf=2, max_features=1.0): 0.7049862074726141
# Mean Squared Error (n_estimators=100, max_depth=10, min_samples_split=2, min_samples_leaf=2, max_features=sqrt): 8.152430572689214
# Mean Squared Error (n_estimators=100, max_depth=10, min_samples_split=2, min_samples_leaf=2, max_features=0.5): 2.303569537819447
# Mean Squared Error (n_estimators=100, max_depth=10, min_samples_split=5, min_samples_leaf=1, max_features=1.0): 0.794150256129953
# Mean Squared Error (n_estimators=100, max_depth=10, min_samples_split=5, min_samples_leaf=1, max_features=sqrt): 7.4904146343899125
# Mean Squared Error (n_estimators=100, max_depth=10, min_samples_split=5, min_samples_leaf=1, max_features=0.5): 2.325968078381158
# Mean Squared Error (n_estimators=100, max_depth=10, min_samples_split=5, min_samples_leaf=2, max_features=1.0): 0.7710503760765224
# Mean Squared Error (n_estimators=100, max_depth=10, min_samples_split=5, min_samples_leaf=2, max_features=sqrt): 8.489655119766681
# Mean Squared Error (n_estimators=100, max_depth=10, min_samples_split=5, min_samples_leaf=2, max_features=0.5): 2.339566927027078
# Mean Squared Error (n_estimators=100, max_depth=20, min_samples_split=2, min_samples_leaf=1, max_features=1.0): 0.8006238359940882
# Mean Squared Error (n_estimators=100, max_depth=20, min_samples_split=2, min_samples_leaf=1, max_features=sqrt): 7.510508757491216
# Mean Squared Error (n_estimators=100, max_depth=20, min_samples_split=2, min_samples_leaf=1, max_features=0.5): 2.449629064419471
# Mean Squared Error (n_estimators=100, max_depth=20, min_samples_split=2, min_samples_leaf=2, max_features=1.0): 0.7373177183942361
# Mean Squared Error (n_estimators=100, max_depth=20, min_samples_split=2, min_samples_leaf=2, max_features=sqrt): 7.655069115443085
# Mean Squared Error (n_estimators=100, max_depth=20, min_samples_split=2, min_samples_leaf=2, max_features=0.5): 2.3983456093697204
# Mean Squared Error (n_estimators=100, max_depth=20, min_samples_split=5, min_samples_leaf=1, max_features=1.0): 0.9535904732430501
# Mean Squared Error (n_estimators=100, max_depth=20, min_samples_split=5, min_samples_leaf=1, max_features=sqrt): 7.889183544686425
# Mean Squared Error (n_estimators=100, max_depth=20, min_samples_split=5, min_samples_leaf=1, max_features=0.5): 2.4797693890943493
# Mean Squared Error (n_estimators=100, max_depth=20, min_samples_split=5, min_samples_leaf=2, max_features=1.0): 0.7306269910810763
# Mean Squared Error (n_estimators=100, max_depth=20, min_samples_split=5, min_samples_leaf=2, max_features=sqrt): 8.345346418556733
# Mean Squared Error (n_estimators=100, max_depth=20, min_samples_split=5, min_samples_leaf=2, max_features=0.5): 2.4957066743981247
# Mean Squared Error (n_estimators=200, max_depth=None, min_samples_split=2, min_samples_leaf=1, max_features=1.0): 0.8244832013378363
# Mean Squared Error (n_estimators=200, max_depth=None, min_samples_split=2, min_samples_leaf=1, max_features=sqrt): 6.940882238014866
# Mean Squared Error (n_estimators=200, max_depth=None, min_samples_split=2, min_samples_leaf=1, max_features=0.5): 2.3864969806197616
# Mean Squared Error (n_estimators=200, max_depth=None, min_samples_split=2, min_samples_leaf=2, max_features=1.0): 0.7304013749614906
# Mean Squared Error (n_estimators=200, max_depth=None, min_samples_split=2, min_samples_leaf=2, max_features=sqrt): 7.184072956533241
# Mean Squared Error (n_estimators=200, max_depth=None, min_samples_split=2, min_samples_leaf=2, max_features=0.5): 2.34730374361748
# Mean Squared Error (n_estimators=200, max_depth=None, min_samples_split=5, min_samples_leaf=1, max_features=1.0): 0.8604274654507961
# Mean Squared Error (n_estimators=200, max_depth=None, min_samples_split=5, min_samples_leaf=1, max_features=sqrt): 7.782026963660251
# Mean Squared Error (n_estimators=200, max_depth=None, min_samples_split=5, min_samples_leaf=1, max_features=0.5): 2.4261490920580844
# Mean Squared Error (n_estimators=200, max_depth=None, min_samples_split=5, min_samples_leaf=2, max_features=1.0): 0.7294990617625785
# Mean Squared Error (n_estimators=200, max_depth=None, min_samples_split=5, min_samples_leaf=2, max_features=sqrt): 7.628117458836013
# Mean Squared Error (n_estimators=200, max_depth=None, min_samples_split=5, min_samples_leaf=2, max_features=0.5): 2.5050323726403088
# Mean Squared Error (n_estimators=200, max_depth=10, min_samples_split=2, min_samples_leaf=1, max_features=1.0): 0.7849659846200744
# Mean Squared Error (n_estimators=200, max_depth=10, min_samples_split=2, min_samples_leaf=1, max_features=sqrt): 7.020609268362862
# Mean Squared Error (n_estimators=200, max_depth=10, min_samples_split=2, min_samples_leaf=1, max_features=0.5): 2.547289698361956
# Mean Squared Error (n_estimators=200, max_depth=10, min_samples_split=2, min_samples_leaf=2, max_features=1.0): 0.7191406585219111
# Mean Squared Error (n_estimators=200, max_depth=10, min_samples_split=2, min_samples_leaf=2, max_features=sqrt): 7.642338831233663
# Mean Squared Error (n_estimators=200, max_depth=10, min_samples_split=2, min_samples_leaf=2, max_features=0.5): 2.32689551023544
# Mean Squared Error (n_estimators=200, max_depth=10, min_samples_split=5, min_samples_leaf=1, max_features=1.0): 0.7930403389641226
# Mean Squared Error (n_estimators=200, max_depth=10, min_samples_split=5, min_samples_leaf=1, max_features=sqrt): 7.484386348934446
# Mean Squared Error (n_estimators=200, max_depth=10, min_samples_split=5, min_samples_leaf=1, max_features=0.5): 2.4341125759588005
# Mean Squared Error (n_estimators=200, max_depth=10, min_samples_split=5, min_samples_leaf=2, max_features=1.0): 0.7505579181025176
# Mean Squared Error (n_estimators=200, max_depth=10, min_samples_split=5, min_samples_leaf=2, max_features=sqrt): 8.333869826694555
# Mean Squared Error (n_estimators=200, max_depth=10, min_samples_split=5, min_samples_leaf=2, max_features=0.5): 2.404882088432096
# Mean Squared Error (n_estimators=200, max_depth=20, min_samples_split=2, min_samples_leaf=1, max_features=1.0): 0.8244832013378363
# Mean Squared Error (n_estimators=200, max_depth=20, min_samples_split=2, min_samples_leaf=1, max_features=sqrt): 6.940882238014866
# Mean Squared Error (n_estimators=200, max_depth=20, min_samples_split=2, min_samples_leaf=1, max_features=0.5): 2.3864969806197616
# Mean Squared Error (n_estimators=200, max_depth=20, min_samples_split=2, min_samples_leaf=2, max_features=1.0): 0.7304013749614906
# Mean Squared Error (n_estimators=200, max_depth=20, min_samples_split=2, min_samples_leaf=2, max_features=sqrt): 7.184072956533241
# Mean Squared Error (n_estimators=200, max_depth=20, min_samples_split=2, min_samples_leaf=2, max_features=0.5): 2.34730374361748
# Mean Squared Error (n_estimators=200, max_depth=20, min_samples_split=5, min_samples_leaf=1, max_features=1.0): 0.8604274654507961
# Mean Squared Error (n_estimators=200, max_depth=20, min_samples_split=5, min_samples_leaf=1, max_features=sqrt): 7.782026963660251
# Mean Squared Error (n_estimators=200, max_depth=20, min_samples_split=5, min_samples_leaf=1, max_features=0.5): 2.4261490920580844
# Mean Squared Error (n_estimators=200, max_depth=20, min_samples_split=5, min_samples_leaf=2, max_features=1.0): 0.7294990617625785
# Mean Squared Error (n_estimators=200, max_depth=20, min_samples_split=5, min_samples_leaf=2, max_features=sqrt): 7.628117458836013
# Mean Squared Error (n_estimators=200, max_depth=20, min_samples_split=5, min_samples_leaf=2, max_features=0.5): 2.5050323726403088
